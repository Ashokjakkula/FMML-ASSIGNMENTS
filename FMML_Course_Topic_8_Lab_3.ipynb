# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashokjakkula/FMML-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 16:06:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  94.5MB/s    in 0.7s
#
# 2024-03-28 16:06:46 (94.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14150  1801.07546v1  Selection hyper-heuristics are randomised sear...    cs
# 22195  1507.04505v1  We highlight a pitfall when applying stochasti...  stat
# 29558  1709.07598v1  Digital retouching of face images is becoming ...    cs
# 31708  cs/0611011v1  Recent advances in machine learning make it po...    cs
# 5461    1406.2541v1  We propose a novel information-theoretic appro...  stat
# ...             ...                                                ...   ...
# 35787   1208.1187v1  Creating and monitoring competitive and cost-e...    cs
# 37086  1606.09242v1  A probabilistic program defines a probability ...    cs
# 7443   1712.09763v1  Autoregressive generative models consistently ...    cs
# 13019   1403.1124v2  Despite the major advances taken in causal mod...  stat
# 2684   1706.00400v2  Variational autoencoders (VAEs) learn represen...  stat
#
#                                                    title  year  \
# 14150  Hyper-heuristics Can Achieve Optimal Performan...  2018
# 22195  On the Convergence of Stochastic Variational I...  2015
# 29558  Demography-based Facial Retouching Detection u...  2017
# 31708            Hedging predictions in machine learning  2006
# 5461   Predictive Entropy Search for Efficient Global...  2014
# ...                                                  ...   ...
# 35787  Toward an Integrated Framework for Automated D...  2012
# 37086  Swift: Compiled Inference for Probabilistic Pr...  2016
# 7443   PixelSNAIL: An Improved Autoregressive Generat...  2017
# 13019  Estimating complex causal effects from incompl...  2014
# 2684   Learning Disentangled Representations with Sem...  2017
#
#                                                 keywords
# 14150  [selection, heuristics, randomised, methodolog...
# 22195  [highlight, stochastic, variational, inference...
# 29558  [retouching, widespread, introduction, researc...
# 31708  [efficient, prediction, algorithms, parameters...
# 5461   [information, theoretic, optimization, predict...
# ...                                                  ...
# 35787  [monitoring, competitive, effective, advertise...
# 37086  [probabilistic, probability, structures, proba...
# 7443   [autoregressive, generative, consistently, est...
# 13019  [causality, unfamiliar, statisticians, demonst...
# 2684   [variational, autoencoders, representations, p...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14150    [selection, heuristics, randomised, methodolog...
# 22195    [highlight, stochastic, variational, inference...
# 29558    [retouching, widespread, introduction, researc...
# 31708    [efficient, prediction, algorithms, parameters...
# 5461     [information, theoretic, optimization, predict...
#                                ...
# 13668    [financial, forecasting, estimation, financial...
# 32602    [restricted, boltzmann, boltzmann, multiplicat...
# 34053    [influenza, respiratory, virtually, substantia...
# 33       [recurrent, description, motivated, exploratio...
# 29345    [cooperative, basketball, intention, predictio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8905 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="92440a78-d13f-4415-862a-dbe7ffcd78c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92440a78-d13f-4415-862a-dbe7ffcd78c9")) {                    Plotly.newPlot(                        "92440a78-d13f-4415-862a-dbe7ffcd78c9",                        [{"x":["realistic","mechanisms","rigorously","performance","combinatorial","successful","heuristics","permutation","situations","experimental","optimisation","difference","efficient","methodologies","inefficient","probability","heuristic","generalised","relatively","reasonable","randomised","perturbing","benchmark","generalise","currently","particular","outperforms","operators","parameter","promising","perturbation","necessary","increases","reinforcement","iteration","algorithm","selection","investigate","stochastic","distribution","approximated","approximation","variables","highlight","variational","convergence","factorizes","experimentally","practical","inference","exponential","introduce","combinations","different","introduction","autoencoder","algorithms","retouching","contribution","considered","detection","demographic","supervised","widespread","introduced","demography","classification","belonging","information","demographics","experiments","incorporating","researchers","conducted","generalized","assumption","randomness","successfully","erroneous","generated","technique","efficiency","predictions","independently","available","selecting","parameters","describes","including","automatically","reliability","prediction","neighbours","statistical","quantitative","confidence","traditional","regression","remaining","machinery","increased","maximizes","functions","optimization","significant","hyperparameters","intractable","predictive","acquisition","reformulation","treatment","applications","alternatives","differential","reduction","approximations","theoretic","synthetic","furthermore","evaluation","background","performing","irrelevant","adaptively","segmentation","effectively","approaches","published","foreground","computing","extracting","computationally","considerably","overlapping","magnitude","estimation","existence","transforming","corrected","corresponding","histogram","particularly","illustrate","calibration","therefore","constraint","orientations","optimizing","structure","vanishing","revealing","applicable","normalized","performed","distortion","correction","distorted","competitive","practitioners","weaknesses","convolutional","successes","opportunity","limitations","demanding","recognizable","carefully","performances","strengths","properties","architectures","recognition","demonstrate","relaxation","nonconvex","dictionary","empirical","kronecker","establishing","dictionaries","challenging","represent","rearranged","structured","representation","multidimensional","underlying","estimator","annotation","favorably","annotations","objective","dirichlet","additional","simultaneously","specifically","discriminative","allocation","framework","extension"],"y":[62,53,3,874,38,80,37,17,41,386,16,65,406,17,15,142,42,11,54,38,3,3,203,6,65,272,259,52,118,119,12,75,60,121,39,820,141,153,135,208,8,113,145,31,48,115,3,48,134,201,41,310,46,770,33,20,587,2,67,122,352,8,189,14,137,2,512,13,720,1,604,76,76,76,84,86,7,98,8,164,262,156,87,36,289,47,247,86,277,195,20,210,5,160,61,48,185,112,19,3,37,5,238,298,224,8,22,62,35,6,37,456,23,34,87,37,53,128,155,275,68,85,11,38,206,109,421,46,14,148,72,88,35,25,44,181,37,12,9,144,26,86,69,9,140,86,5,49,328,10,6,55,32,125,24,25,11,114,18,9,373,10,10,55,6,4,24,39,19,203,115,380,522,19,7,52,141,0,21,17,249,124,2,101,401,17,144,28,50,21,52,145,18,105,105,160,99,29,510,79],"type":"bar"},{"x":["realistic","mechanisms","rigorously","performance","combina ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>You</span> <span style=''>Do</span> <span style=''>I</span> <span style=''>Learn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style=''>Multi</span> <span style=''>User</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>egocentric</span> <span style=''>Approach</span> <span style=''>Towards</span> <span style=''>Video</span> <span style=''>Based</span> <span style=''>Guidance</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>approach</span> <span style=''>towards</span> <span style='background-color:rgba(0, 255, 0, 0.3829787234042554);'>automatically</span> <span style='background-color:rgba(0, 255, 0, 0.5483870967741935);'>extracting</span> <span style=''>video</span> <span style=''>based</span> <span style=''>guidance</span> <span style=''>on</span> <span style=''>object</span> <span style=''>usage</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>egocentric</span> <span style=''>video</span> <span style=''>and</span> <span style=''>wearable</span> <span style=''>gaze</span> <span style=''>tracking</span> <span style='background-color:rgba(0, 255, 0, 0.3217391304347826);'>collected</span> <span style=''>from</span> <span style=''>multiple</span> <span style=''>users</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>tasks</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>i)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovers</span> <span style=''>task</span> <span style=''>relevant</span> <span style=''>objects</span> <span style=''>ii)</span> <span style=''>builds</span> <span style=''>a</span> <span style=''>model</span> <span style=''>for</span> <span style=''>each</span> <span style=''>iii)</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>distinguishes</span> <span style='background-color:rgba(0, 255, 0, 0.3207547169811321);'>different</span> <span style=''>ways</span> <span style=''>in</span> <span style=''>which</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.4838709677419355);'>discovered</span> <span style=''>object</span> <span style=''>has</span> <span style=''>been</span> <span style=''>used</span> <span style=''>and</span> <span style=''>iv)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovers</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>between</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>The</span> <span style=''>work</span> <span style='background-color:rgba(0, 255, 0, 0.5652173913043479);'>investigates</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.9444444444444445);'>appearance</span> <span style=''>position</span> <span style=''>motion</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33628318584070804);'>attention</span> <span style=''>and</span> <span style=''>presents</span> <span style=''>results</span> <span style=''>using</span> <span style=''>each</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.39795918367346933);'>combination</span> <span style=''>of</span> <span style=''>relevant</span> <span style=''>features</span> <span style=''>Moreover</span> <span style=''>an</span> <span style=''>online</span> <span style=''>scalable</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3722627737226278);'>presented</span> <span style=''>and</span> <span style=''>is</span> <span style=''>compared</span> <span style=''>to</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Redundancy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Techniques</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Straggler</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mitigation</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>and</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Performance</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>and</span> <span style=''>learning</span> <span style=''>systems</span> <span style=''>is</span> <span style=''>bottlenecked</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straggler</span> <span style=''>nodes</span> <span style=''>and</span> <span style=''>slow</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communication</span> <span style=''>links</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>delay</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>where</span> <span style=''>the</span> <span style=''>dataset</span> <span style=''>is</span> <span style=''>encoded</span> <span style=''>to</span> <span style=''>have</span> <span style=''>an</span> <span style=''>over</span> <span style=''>complete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>with</span> <span style=''>built</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>redundancy</span> <span style=''>and</span> <span style=''>the</span> <span style=''>straggling</span> <span style=''>nodes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>system</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dynamically</span> <span style=''>left</span> <span style=''>out</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>at</span> <span style=''>every</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>whose</span> <span style=''>loss</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compensated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>embedded</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>redundancy</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>oblivious</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>several</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>on</span> <span style=''>encoded</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>L</span> <span style=''>BFGS</span> <span style=''>proximal</span> <span style=''>gradient</span> <span style=''>under</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parallelism< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Lower</span> <span style=''>Bounds</span> <span style=''>on</span> <span style=''>Active</span> <span style=''>Learning</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Graphical</span> <span style=''>Model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.42424242424242425);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>field</span> <span style=''>with</span> <span style=''>the</span> <span style=''>added</span> <span style=''>twist</span> <span style=''>that</span> <span style=''>the</span> <span style=''>decoding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteratively</span> <span style=''>choose</span> <span style=''>which</span> <span style=''>subsets</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>to</span> <span style=''>sample</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>samples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>an</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>setting</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>Considering</span> <span style=''>both</span> <span style=''>Ising</span> <span style=''>and</span> <span style=''>Gaussian</span> <span style=''>models</span> <span style=''>we</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>recovery</span> <span style=''>within</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style=''>degree</span> <span style=''>bounded</span> <span style=''>graphs</span> <span style=''>Our</span> <span style=''>main</span> <span style=''>results</span> <span style=''>are</span> <span style=''>minimax</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>active</span> <span style=''>setting</span> <span style=''>that</span> <span style=''>match</span> <span style=''>the</span> <span style=''>best</span> <span style=''>known</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>passive</span> <span style=''>setting</span> <span style=''>which</span> <span style=''>in</span> <span style=''>turn</span> <span style=''>are</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style=''>tight</span> <span style=''>in</span> <span style=''>several</span> <span style=''>cases</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>Our</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Fanos</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inequality</span> <span style=''>along</span> <span style=''>with</span> <span style=''>novel</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.33209990749306 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Block</span> <span style=''>CUR</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposing</span> <span style=''>Large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributed</span> <span style=''>Matrices</span> <br/><br/><span style=''>A</span> <span style=''>common</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style=''>sampled</span> <span style=''>rows</span> <span style=''>and</span> <span style=''>columns</span> <span style=''>known</span> <span style=''>as</span> <span style=''>CUR</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style=''>in</span> <span style=''>many</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environments</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>sample</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>rows</span> <span style=''>or</span> <span style=''>columns</span> <span style=''>of</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>is</span> <span style=''>limited</span> <span style=''>by</span> <span style=''>either</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>or</span> <span style=''>cost</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>by</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predefined</span> <span style=''>blocks</span> <span style=''>of</span> <span style=''>columns</span> <span style=''>(or</span> <span style=''>rows)</span> <span style=''>from</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>This</span> <span style=''>regime</span> <span style=''>is</span> <span style=''>commonly</span> <span style=''>found</span> <span style=''>when</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>across</span> <span style=''>multiple</span> <span style=''>nodes</span> <span style=''>in</span> <span style=''>a</span> <span style=''>compute</span> <span style=''>cluster</span> <span style=''>where</span> <span style=''>such</span> <span style=''>blocks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correspond</span> <span style=''>to</span> <span style=''>columns</span> <span style=''>(or</span> <span style=''>rows)</span> <span style=''>of</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>stored</span> <span style=''>on</span> <span style=''>the</span> <span style=''>same</span> <span style=''>node</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retrieved</span> <span style=''>with</span> <span style=''>much</span> <span style=''>less</span> <span style=''>overhead</span> <span style=''>than</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>retrieving</span> <span style='background-color:rgba(255, 0, 0, 0 ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10304532577903683)
# 	experimental (0.136685552407932)
# 	architecture (0.08569405099150142)
# 	representation (0.1419971671388102)
# 	segmentation (0.07294617563739376)
# 	detection (0.12464589235127478)
# 	different (0.2726628895184136)
# 	information (0.254957507082153)
# 	convolutional (0.13208215297450424)
# 	recognition (0.13456090651558072)
#
# Some Statistics words are:
# 	optimization (0.18977732793522267)
# 	demonstrate (0.26973684210526316)
# 	algorithm (0.3866396761133603)
# 	theoretical (0.15182186234817813)
# 	statistical (0.16447368421052633)
# 	distribution (0.18319838056680163)
# 	estimation (0.17813765182186234)
# 	dimensional (0.1902834008097166)
# 	inference (0.19939271255060728)
# 	regression (0.18775303643724697)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9fdee89a-013d-4454-bdcb-3f144e4d6e26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fdee89a-013d-4454-bdcb-3f144e4d6e26")) {                    Plotly.newPlot(                        "9fdee89a-013d-4454-bdcb-3f144e4d6e26",                        [{"x":["realistic","mechanisms","rigorously","performance","combinatorial","successful","heuristics","permutation","situations","experimental","optimisation","difference","efficient","methodologies","inefficient","probability","heuristic","generalised","relatively","reasonable","randomised","perturbing","benchmark","generalise","currently","particular","outperforms","operators","parameter","promising","perturbation","necessary","increases","reinforcement","iteration","algorithm","selection","investigate","stochastic","distribution","approximated","approximation","variables","highlight","variational","convergence","factorizes","experimentally","practical","inference","exponential","introduce","combinations","different","introduction","autoencoder","algorithms","retouching","contribution","considered","detection","demographic","supervised","widespread","introduced","demography","classification","belonging","information","demographics","experiments","incorporating","researchers","conducted","generalized","assumption","randomness","successfully","erroneous","generated","technique","efficiency","predictions","independently","available","selecting","parameters","describes","including","automatically","reliability","prediction","neighbours","statistical","quantitative","confidence","traditional","regression","remaining","machinery","increased","maximizes","functions","optimization","significant","hyperparameters","intractable","predictive","acquisition","reformulation","treatment","applications","alternatives","differential","reduction","approximations","theoretic","synthetic","furthermore","evaluation","background","performing","irrelevant","adaptively","segmentation","effectively","approaches","published","foreground","computing","extracting","computationally","considerably","overlapping","magnitude","estimation","existence","transforming","corrected","corresponding","histogram","particularly","illustrate","calibration","therefore","constraint","orientations","optimizing","structure","vanishing","revealing","applicable","normalized","performed","distortion","correction","distorted","competitive","practitioners","weaknesses","convolutional","successes","opportunity","limitations","demanding","recognizable","carefully","performances","strengths","properties","architectures","recognition","demonstrate","relaxation","nonconvex","dictionary","empirical","kronecker","establishing","dictionaries","challenging","represent","rearranged","structured","representation","multidimensional","underlying","estimator","annotation","favorably","annotations","objective","dirichlet","additional","simultaneously","specifically","discriminative","allocation","framework","extension","demonstrated","simultaneous","autoregressive","subspaces","embedding","formulation","component","estimating","reconstruction","covariance","assumptions","applicability","extensions","principal","complexity","associated","estimates","protocols","limitation","dependencies","multitask","distinction","environment","environments","neighbors","streaming","simulated","detailing","reviewing","introducing","distributed","filtering","scenarios","adaptation","nonlinear","measurements","communications","alternating","important","computations","literature","outperformed","electronic","unstructured","recurrent","application","extraction","pharmacovigilance","calculated","surveillance","informatics","frameworks","significantly","attribute ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	kronecker
# 	detailing
# 	penalised
# 	blockmodel
# 	hypergraphs
# 	streamline
# 	passenger
# 	datapoints
# 	heteroscedasticity
# 	california
# 	precisions
# 	streamlined
# 	deficient
# 	statistician
# 	extrapolation
# 	particulars
# 	quadrature
# 	precludes
# 	minibatches
# 	blockmodels
# Some words which never appear in Statistics papers:
# 	randomised
# 	retouching
# 	demography
# 	pharmacovigilance
# 	helicopters
# 	quadrotor
# 	reestimation
# 	collision
# 	exchanging
# 	constituency
# 	interlingual
# 	resilience
# 	felzenszwalb
# 	deformable
# 	communicative
# 	affective
# 	electromyography
# 	affordances
# 	fixations
# 	articulated

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0491523356506895e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7541666666666667
